# %% [markdown]
# <a href="https://colab.research.google.com/github/MDAnsaar25/Covid-Analysis/blob/main/Python_Covid_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Example Reading and Viewing the data sets

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/content/drive/MyDrive/Covid dataset.xlsx")

# %%
df.head(5)
# Out:
#         Date   Date_YMD  Daily Confirmed  Daily Deceased
# 0 2020-01-30 2020-01-30                1               0
# 1 2020-01-31 2020-01-31                0               0
# 2 2020-02-01 2020-02-01                0               0
# 3 2020-02-02 2020-02-02                1               0
# 4 2020-02-03 2020-02-03                1               0

# %%
df
# Out:
#           Date   Date_YMD  Daily Confirmed  Daily Deceased
# 0   2020-01-30 2020-01-30                1               0
# 1   2020-01-31 2020-01-31                0               0
# 2   2020-02-01 2020-02-01                0               0
# 3   2020-02-02 2020-02-02                1               0
# 4   2020-02-03 2020-02-03                1               0
# ..         ...        ...              ...             ...
# 715 2022-01-14 2022-01-14           266518             621
# 716 2022-01-15 2022-01-15           271202             314
# 717 2022-01-16 2022-01-16           258089             385
# 718 2022-01-17 2022-01-17           238018             310
# 719 2022-01-18 2022-01-18           282970             441
#
# [720 rows x 4 columns]

# %%
df.head(10)
# Out:
#         Date   Date_YMD  Daily Confirmed  Daily Deceased
# 0 2020-01-30 2020-01-30                1               0
# 1 2020-01-31 2020-01-31                0               0
# 2 2020-02-01 2020-02-01                0               0
# 3 2020-02-02 2020-02-02                1               0
# 4 2020-02-03 2020-02-03                1               0
# 5 2020-02-04 2020-02-04                0               0
# 6 2020-02-05 2020-02-05                0               0
# 7 2020-02-06 2020-02-06                0               0
# 8 2020-02-07 2020-02-07                0               0
# 9 2020-02-08 2020-02-08                0               0

# %%
df.tail(10)
# Out:
#           Date   Date_YMD  Daily Confirmed  Daily Deceased
# 710 2022-01-09 2022-01-09           179123             146
# 711 2022-01-10 2022-01-10           168063             277
# 712 2022-01-11 2022-01-11           221068             411
# 713 2022-01-12 2022-01-12           221069             411
# 714 2022-01-13 2022-01-13           266517              96
# 715 2022-01-14 2022-01-14           266518             621
# 716 2022-01-15 2022-01-15           271202             314
# 717 2022-01-16 2022-01-16           258089             385
# 718 2022-01-17 2022-01-17           238018             310
# 719 2022-01-18 2022-01-18           282970             441

# %%
df.shape
# Out:
# (720, 4)

# %%
df.describe()
# Out:
#                       Date             Date_YMD  Daily Confirmed  \
# count                  720                  720       720.000000
# mean   2021-01-23 12:00:00  2021-01-23 12:00:00     52637.915278
# min    2020-01-30 00:00:00  2020-01-30 00:00:00         0.000000
# 25%    2020-07-27 18:00:00  2020-07-27 18:00:00     10419.250000
# 50%    2021-01-23 12:00:00  2021-01-23 12:00:00     27383.000000
# 75%    2021-07-22 06:00:00  2021-07-22 06:00:00     54300.750000
# max    2022-01-18 00:00:00  2022-01-18 00:00:00    414280.000000
# std                    NaN                  NaN     78522.746943
#
#        Daily Deceased
# count      720.000000
# mean       675.901389
# min          0.000000
# 25%        159.000000
# 50%        387.000000
# 75%        734.750000
# max       6139.000000
# std        932.895333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             720 non-null    datetime64[ns]
#  1   Date_YMD         720 non-null    datetime64[ns]
#  2   Daily Confirmed  720 non-null    int64
#  3   Daily Deceased   720 non-null    int64
# dtypes: datetime64[ns](2), int64(2)
# memory usage: 22.6 KB

# %%
df["Daily Deceased"].tail(25)
# Out:
# 695    361
# 696    349
# 697    293
# 698    302
# 699    268
# 700    220
# 701    406
# 702    284
# 703    123
# 704    124
# 705    534
# 706    325
# 707    302
# 708    285
# 709    327
# 710    146
# 711    277
# 712    411
# 713    411
# 714     96
# 715    621
# 716    314
# 717    385
# 718    310
# 719    441
# Name: Daily Deceased, dtype: int64

# %%
df["Daily Deceased"].value_counts()
# Out:
# Daily Deceased
# 0       48
# 491      6
# 1        6
# 285      5
# 120      4
#         ..
# 589      1
# 1032     1
# 840      1
# 882      1
# 441      1
# Name: count, Length: 509, dtype: int64

# %%
df["Daily Confirmed"].tail(25)
# Out:
# 695      6987
# 696      6531
# 697      6358
# 698      9195
# 699     13154
# 700     16764
# 701     22775
# 702     27553
# 703     33750
# 704     37379
# 705     58097
# 706     90928
# 707    117100
# 708    141986
# 709    159632
# 710    179123
# 711    168063
# 712    221068
# 713    221069
# 714    266517
# 715    266518
# 716    271202
# 717    258089
# 718    238018
# 719    282970
# Name: Daily Confirmed, dtype: int64

# %%
df
# Out:
#           Date   Date_YMD  Daily Confirmed  Daily Deceased
# 0   2020-01-30 2020-01-30                1               0
# 1   2020-01-31 2020-01-31                0               0
# 2   2020-02-01 2020-02-01                0               0
# 3   2020-02-02 2020-02-02                1               0
# 4   2020-02-03 2020-02-03                1               0
# ..         ...        ...              ...             ...
# 715 2022-01-14 2022-01-14           266518             621
# 716 2022-01-15 2022-01-15           271202             314
# 717 2022-01-16 2022-01-16           258089             385
# 718 2022-01-17 2022-01-17           238018             310
# 719 2022-01-18 2022-01-18           282970             441
#
# [720 rows x 4 columns]

# %%
df["Daily Confirmed"].min()
# Out:
# 0

# %%
df["Daily Confirmed"].max()
# Out:
# 414280

# %%
df["Daily Deceased"].max()
# Out:
# 6139

# %%
df["Daily Deceased"].min()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["Daily Confirmed"])

# %%
plt.plot(df["Daily Deceased"])

# %%
#Histogram
plt.hist(df["Daily Confirmed"])
plt.figure(figsize=(7,6))
plt.show()

# %%
#Histogram
plt.hist(df["Daily Deceased"])
plt.figure(figsize=(10,10))
plt.show()

# %%
plt.plot(df[(df['Daily Deceased'] >= 1000) & (df['Daily Deceased'] <= 3000)])
plt.show()
